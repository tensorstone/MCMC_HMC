# %%
########
##HMC##
########
'''
this program will help to find the convergence rate of HMC, in term of magnetic moment
author: Hao SUN
email: sunhopht@gmail.com
'''

import numpy as np
import matplotlib.pyplot as plt
import datetime
import random
random.seed(123)#for duplication



now = datetime.datetime.now()
#the start time

I =15
J =15
#I,J  are the shape of the simulated optical lattice

A = np.empty((I,J))
B = np.empty((I,J))
for i in range(I):
    for j in range(J):
        A[i,j]= 1
        B[i,j]= 1        
        
JKBTMAX = 5 #range of temperature 
Steplen = 0.1 # step length


T = int(JKBTMAX/Steplen) #the number of temperature 
M_C = np.empty((10,T))#the average magnetic moment for every 10 percent result of each T
M_B = np.empty((10,T))
for i in range(10):
    for t in range(T):
        M_C[i,t] = 0
        M_B[i,t] = 0

CYCLE =50
W = CYCLE
####################
PLT_C = np.zeros((T,W,I,J))
PLT_B = np.zeros((T,W,I,J))
####################
for jkbt in range(T):
    Temp = jkbt
    for w in range(W):
        for i in range(I):
            for j in range(J):
                if i==0:
                    im=I-1
                else:
                    im=i-1
                if i==I-1:
                    ip=0
                else:
                    ip=i+1
                if j==0:
                    jm=J-1
                else:
                    jm=j-1
                if j==J-1:
                    jp=0
                else:
                    jp=j+1
                Sumup = 0
                Sumup = A[ip,j]+A[i,jp]+A[im,j]+A[i,jm]
                Timesup = 0
                Timesup = Sumup * A[i,j]
                B[i,j] = - np.sign(Temp*Steplen* np.log(1/random.uniform(0,1)) - 2*Timesup ) *A[i,j]
                A[:,:] = B[:,:]
        PLT_C[jkbt,w,:,:] = A[:,:]
        M_C[np.floor((w)*10/W),jkbt]+= np.sum(A)
        
        for i in range(I):
            for j in range(J):
                if i==0:
                    im=I-1
                else:
                    im=i-1
                if i==I-1:
                    ip=0
                else:
                    ip=i+1
                if j==0:
                    jm=J-1
                else:
                    jm=j-1
                if j==J-1:
                    jp=0
                else:
                    jp=j+1
                Sumup = 0
                Sumup = A[ip,j]+A[i,jp]+A[im,j]+A[i,jm]
                Timesup = 0
                Timesup = Sumup * A[i,j]
                B[i,j] = - np.sign(Temp*Steplen* np.log(1/random.uniform(0,1)) - 2*Timesup ) *A[i,j]
        A[:,:] = B[:,:]
        PLT_B[jkbt,w,:,:] = A[:,:]
        M_B[np.floor((w)*10/W),jkbt]+= np.sum(A)        
        
        
    
    M_C[:,jkbt] /= (W/10)
    M_B[:,jkbt] /= (W/10)
end = datetime.datetime.now()
print("time:",(end-now).total_seconds())
        
        

ii = range(T)
ii = np.asarray(ii)
T_ =(ii[:]*Steplen)
Onsager= I*J*(1-np.sinh(2/T_)**(-4))**0.125
for i in range(len(Onsager)):
    if np.isnan(Onsager[i]):
        Onsager[i]=0

#this is the Onsager solution
# Out:
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:78: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:105: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# time: 7.056568
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:119: RuntimeWarning: divide by zero encountered in true_divide
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:119: RuntimeWarning: invalid value encountered in power

# %%
ii = range(T)
ii = np.asarray(ii)
T_ =(ii[:]*Steplen)
Onsager= I*J*(1-np.sinh(2/T_)**(-4))**0.125
for i in range(len(Onsager)):
    if np.isnan(Onsager[i]):
        Onsager[i]=0
Err_sum = 0
for i in range(10):
    print("Error:",np.sqrt(np.sum((np.abs(M_C[i,:]) - np.abs(Onsager))**2)))
    Err_sum += np.sqrt(np.sum((np.abs(M_C[i,:]) - np.abs(Onsager))**2))
    plt.scatter(ii,np.abs(M_C[i,:]))
    plt.scatter(ii,Onsager,color='red')
    plt.show()
    

print("Err_mean :",Err_sum/10)
# Out:
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in true_divide
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in power
# Error: 92.4671795095
# Error: 69.8048560009
# Error: 54.2332258435
# Error: 66.4884358588
# Error: 108.601624731
# Error: 100.548881617
# Error: 130.499968768
# Error: 118.285126756
# Error: 110.589881491
# Error: 130.03120686
# Err_mean : 98.1550387435

# %%
ii = range(T)
ii = np.asarray(ii)
T_ =(ii[:]*Steplen)
Onsager= I*J*(1-np.sinh(2/T_)**(-4))**0.125
for i in range(len(Onsager)):
    if np.isnan(Onsager[i]):
        Onsager[i]=0
Err_sum = 0
for i in range(10):
    print("Error:",np.sqrt(np.sum((np.abs(M_B[i,:]) - np.abs(Onsager))**2)))
    Err_sum += np.sqrt(np.sum((np.abs(M_B[i,:]) - np.abs(Onsager))**2))
    plt.scatter(ii,np.abs(M_B[i,:]))
    plt.scatter(ii,Onsager,color='red')
    plt.show()
    

print("Err_mean :",Err_sum/10)
# Out:
# Error: 87.7752376338
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in true_divide
# /Users/sunhop/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in power
# Error: 68.2027258902
# Error: 63.677587244
# Error: 77.1629788765
# Error: 118.126419917
# Error: 122.722813089
# Error: 144.907403603
# Error: 126.5908541
# Error: 121.586432965
# Error: 134.523709494
# Err_mean : 106.527616281
